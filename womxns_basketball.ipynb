# %%
import json
import re
import requests
import scrapy
import pandas as pd

# %%
#access permission
headers = {'User-Agent': 'UNC Journo Class'}

#stores url page information in sel
resp = requests.get('http://goheels.com/roster.aspx?path=wbball&print=true', headers=headers)
body_str = resp.content.decode('utf-8')
sel = scrapy.Selector(text=body_str)

# %%
table = sel.css('table')[0]
table
# Out:
# <Selector xpath='descendant-or-self::table' data='<table class="sidearm-table sidearm-tabl'>

# %%
#extracts the string value of the table headers of the table of players
cols = table.css('th').xpath('string()').extract()
cols
# Out:
# ['No.', 'Name', 'Pos.', 'Ht.', 'Yr.', 'Hometown / High School']

# %%
#stores table rows into rows
rows = table.css('tr')[1:]

# %%
players = []

#goes through every row and stores its link 
for r in rows:
    data = {}
    for i, d in enumerate(r.css('td')):
        a = d.css('a')
        if a:
            t = a.xpath('text()').extract()[0]
            data['href'] = a.xpath('@href').extract()[0]
        else:
            t = d.xpath('text()').extract()[0]
        data[cols[i]] = t
    players.append(data)

# %%
players
# Out:
# [{'Hometown / High School': 'Savage, Minn. / Shakopee',
#   'Ht.': '6-2',
#   'Name': 'Taylor Koenen',
#   'No.': '1',
#   'Pos.': 'G',
#   'Yr.': 'So.',
#   'href': '/roster.aspx?rp_id=12642'},
#  {'Hometown / High School': 'Richmond, Va. / Cosby',
#   'Ht.': '6-0',
#   'Name': 'Jocelyn Jones',
#   'No.': '4',
#   'Pos.': 'G',
#   'Yr.': 'R-Fr.',
#   'href': '/roster.aspx?rp_id=12643'},
#  {'Hometown / High School': 'Wesley Chapel, N.C. / Weddington',
#   'Ht.': '5-11',
#   'Name': 'Stephanie Watts',
#   'No.': '5',
#   'Pos.': 'G',
#   'Yr.': 'Jr.',
#   'href': '/roster.aspx?rp_id=12644'},
#  {'Hometown / High School': 'Cove City, N.C. / West Craven',
#   'Ht.': '5-8',
#   'Name': 'Jamie Cherry',
#   'No.': '10',
#   'Pos.': 'G',
#   'Yr.': 'Sr.',
#   'href': '/roster.aspx?rp_id=12645'},
#  {'Hometown / High School': 'Newburgh, Ind. / Reitz Memorial',
#   'Ht.': '6-4',
#   'Name': 'Emily Sullivan',
#   'No.': '11',
#   'Pos.': 'F',
#   'Yr.': 'So.',
#   'href': '/roster.aspx?rp_id=12646'},
#  {'Hometown / High School': 'Raleigh, N.C. / Millbrook',
#   'Ht.': '5-10',
#   'Name': 'Dazia Powell',
#   'No.': '13',
#   'Pos.': 'G',
#   'Yr.': 'Fr.',
#   'href': '/roster.aspx?rp_id=12647'},
#  {'Hometown / High School': 'Chapel Hill, N.C. / Durham Academy',
#   'Ht.': '5-8',
#   'Name': 'Liz Roberts',
#   'No.': '14',
#   'Pos.': 'G',
#   'Yr.': 'So.',
#   'href': '/roster.aspx?rp_id=12648'},
#  {'Hometown / High School': 'Raleigh, N.C. / Cardinal Gibbons',
#   'Ht.': '6-0',
#   'Name': 'Olivia Smith',
#   'No.': '15',
#   'Pos.': 'G',
#   'Yr.': 'So.',
#   'href': '/roster.aspx?rp_id=12649'},
#  {'Hometown / High School': 'Purlear, N.C. / Forest Trail Academy',
#   'Ht.': '5-8',
#   'Name': 'Leah Church',
#   'No.': '20',
#   'Pos.': 'G',
#   'Yr.': 'Fr.',
#   'href': '/roster.aspx?rp_id=12650'},
#  {'Hometown / High School': 'Tarboro, N.C. / Page/Vanderbilt',
#   'Ht.': '5-9',
#   'Name': 'Paris Kea',
#   'No.': '22',
#   'Pos.': 'G',
#   'Yr.': 'R-Jr.',
#   'href': '/roster.aspx?rp_id=12651'},
#  {'Hometown / High School': 'Orlando, Fla. / Lake Highland Prep',
#   'Ht.': '5-10',
#   'Name': 'Destinee Walker',
#   'No.': '24',
#   'Pos.': 'G',
#   'Yr.': 'Jr.',
#   'href': '/roster.aspx?rp_id=12652'},
#  {'Hometown / High School': 'Columbia, S.C. / Dreher',
#   'Ht.': '6-2',
#   'Name': 'Jaelynn Murray',
#   'No.': '30',
#   'Pos.': 'F',
#   'Yr.': 'Fr.',
#   'href': '/roster.aspx?rp_id=12653'},
#  {'Hometown / High School': 'Dorchester, England / Hamden Country Day',
#   'Ht.': '6-6',
#   'Name': 'Naomi Van Nes',
#   'No.': '34',
#   'Pos.': 'C',
#   'Yr.': 'So.',
#   'href': '/roster.aspx?rp_id=12654'},
#  {'Hometown / High School': 'Matthews, N.C. / Providence Day School',
#   'Ht.': '6-4',
#   'Name': 'Janelle Bailey',
#   'No.': '44',
#   'Pos.': 'C',
#   'Yr.': 'Fr.',
#   'href': '/roster.aspx?rp_id=12655'}]

# %%
def getBio(player):
    player_url = 'http://goheels.com' + player['href']
    #print('bio', player_url)
    resp = requests.get(player_url, headers=headers)
    player_txt = resp.content.decode('utf-8')
    sel = scrapy.Selector(text=player_txt)
    player['sel'] = sel
    player['bio'] = sel.css('#sidearm-roster-player-bio').xpath('string()').extract()[0]
    player['img'] = sel.css('.sidearm-roster-player-image img').xpath('@src').extract()[0]

# %%
js_obj_rx = re.compile(r'.*?responsive-roster-bio\.ashx.*?(?P<obj>{.*?})')

def getStats(player):
    text = player['sel'].xpath('string()').extract()[0]
    parts = text.split('$.getJSON("/services/')[1:]
    captured = js_obj_rx.findall(''.join(parts))
    clean_objs = []
    for obj_str in captured:
        if 'stats' not in obj_str:
            continue

        obj_str = obj_str.replace('{', '').replace('}', '')
        obj_str = obj_str.replace("'", '').replace('"', '')
        obj_pairs = obj_str.split(',')
        obj_pairs = [x.split(":") for x in obj_pairs]
        clean_pairs = []
        for pair in obj_pairs:
            clean_pairs.append(['"{}"'.format(p.strip()) for p in pair])
        colonized = [":".join(p) for p in clean_pairs]
        commas = ','.join(colonized)
        json_str = "{" + commas + "}"
        clean_objs.append(json.loads(json_str))
    
    player['stats_url'] = stats_url = (
        "http://goheels.com/services/responsive-roster-bio.ashx?"
        "type={type}&rp_id={rp_id}&path={path}&year={year}"
        "&player_id={player_id}"
    ).format(**clean_objs[0])
    
    #print('stats', stats_url)
    
    #PARSE AND CLEAN STATS DATA
    resp = requests.get(stats_url, headers=headers)
    stats_str = resp.content.decode('utf-8')
    sel = scrapy.Selector(text=stats_str)
    if sel.css('table').xpath('string()').extract() != []:
        table = sel.css('table')[0]
        caption = table.css('caption').xpath('string()').extract()
        #print(caption)
        if caption != ['Career Statistics']:
            table = sel.css('table')[1]
    
        #career statistics
        cols = table.css('thead').css('tr').css('th')[1:].xpath('string()').extract()
        #print(cols)
        
        list_stats = []
        #get total career statistics
        row_data = table.css('tfoot')[0].css('tr')[0].css('td').xpath('string()').extract()
        #print(row_data)
        total_cs = list(zip(cols, row_data))
        stat_item_1 = {"Total Career Statistics" : total_cs}
        list_stats.append(stat_item_1)
        
        #get other seasons statistics
        i = 0
        for seasons in table.css('tbody')[0].css('tr').css('th').xpath('string()').extract():
            row_data = table.css('tbody')[0].css('tr')[i].css('td').xpath('string()').extract()
            season = row_data = table.css('tbody')[0].css('tr')[i].css('th').xpath('string()').extract()
            i = i + 1
            #print(season)
            #print(row_data)
            season_cs = list(zip(cols, row_data))
            stat_item_2 = {str(season) : total_cs}
            list_stats.append(stat_item_2)
        
        player['raw_stats'] = list_stats
        
#         for p in player['raw_stats']:
#             print("hi")
#             clean_pairs = []
#             clean_p = str(p).replace("(", '').replace(")", '')
#             clean_p = clean_p.replace("[", '{').replace("]", '}')
#             print(clean_p[1])
#             print(clean_p)

# %%
for p in players:
    getBio(p)
    getStats(p)

# %%
players[0]
# Out:
# {'Hometown / High School': 'Savage, Minn. / Shakopee',
#  'Ht.': '6-2',
#  'Name': 'Taylor Koenen',
#  'No.': '1',
#  'Pos.': 'G',
#  'Yr.': 'So.',
#  'bio': "\r\n                        Biography\r\n                                                    \r\n                            FRESHMAN SEASON 2016-17\r\nAveraged 6.6 points and 5.1 rebounds in first season at North Carolina • Played in all 31 games and started 12 of the final 13 games of the season • Finished the year strong by averaging 10.0 points and a team-leading 7.4 rebounds in the last five games of the season • Registered first career double-double with 11 points and 11 rebounds in the win over Pitt in the first round of the ACC Tournament • Scored a season-high 17 points in the victory over Georgia Tech • Scored in double figures in six games overall, including four of the last six games of 2016-17.\xa0\r\n\r\nPREP/PERSONAL\r\nFive-star rated by ESPN • Ranked 11th best guard and 43rd overall in 2016 class by ESPN • Top-ranked player in the state of Minnesota by Breakdown Sports USA • 2016 Gatorade Minnesota Player of the Year • Earned 15 varsity letters (six in tennis, five in basketball and four in softball) • First Shakopee girl or boy basketball player to score 2,000 career points • Holds eight school records including points, three-pointers, rebounds, assists and steals • Academic all-state team member, ranking in the top 10 percent of her class of nearly 500 students • Favorite high school memory was a three-quarter court shot as a sophomore that ended up on ESPN's Top10 Plays • Named all-conference five times in basketball and tennis and twice in softball • Averaged 21.1 points, 8.1 rebounds, 3.3 assets and 3.2 steals per game as a senior • First team Associated Press All-State as a junior in 2015 • Averaged 21 points, eight rebounds, four assists, three steals and two blocks per game in junior season • Four-time all-academic selection • Competed for Minnesota Stars for two years and Minnesota Fury for six years • Daughter of Doug and Kelli Koenen, and has a younger brother Tanner.\r\n                        \r\n                    ",
#  'href': '/roster.aspx?rp_id=12642',
#  'img': '/images/2017/10/2/Koenen_Taylor_2017_84.jpg?width=300',
#  'raw_stats': [{'Total Career Statistics': [('GP', '62'),
#     ('GS', '43'),
#     ('Minutes', '1916'),
#     ('Totals', '30.9'),
#     ('3-Point', '178'),
#     ('Free-Throws', '523'),
#     ('Rebounds', '.340'),
#     ('PF', '32'),
#     ('FO', '181'),
#     ('AST', '.177'),
#     ('AST/G', '67'),
#     ('T/O', '111'),
#     ('BLK', '.604'),
#     ('STL', '114'),
#     ('PTS', '255'),
#     ('AVG', '369'),
#     ('MIN', '6.0'),
#     ('AVG', '137'),
#     ('FG', '3'),
#     ('FGA', '161'),
#     ('PCT', '2.6'),
#     ('FG', '150'),
#     ('FGA', '44'),
#     ('PCT', '56'),
#     ('FT', '455'),
#     ('FTA', '7.3')]},
#   {"['2016-17']": [('GP', '62'),
#     ('GS', '43'),
#     ('Minutes', '1916'),
#     ('Totals', '30.9'),
#     ('3-Point', '178'),
#     ('Free-Throws', '523'),
#     ('Rebounds', '.340'),
#     ('PF', '32'),
#     ('FO', '181'),
#     ('AST', '.177'),
#     ('AST/G', '67'),
#     ('T/O', '111'),
#     ('BLK', '.604'),
#     ('STL', '114'),
#     ('PTS', '255'),
#     ('AVG', '369'),
#     ('MIN', '6.0'),
#     ('AVG', '137'),
#     ('FG', '3'),
#     ('FGA', '161'),
#     ('PCT', '2.6'),
#     ('FG', '150'),
#     ('FGA', '44'),
#     ('PCT', '56'),
#     ('FT', '455'),
#     ('FTA', '7.3')]},
#   {"['2017-18']": [('GP', '62'),
#     ('GS', '43'),
#     ('Minutes', '1916'),
#     ('Totals', '30.9'),
#     ('3-Point', '178'),
#     ('Free-Throws', '523'),
#     ('Rebounds', '.340'),
#     ('PF', '32'),
#     ('FO', '181'),
#     ('AST', '.177'),
#     ('AST/G', '67'),
#     ('T/O', '111'),
#     ('BLK', '.604'),
#     ('STL', '114'),
#     ('PTS', '255'),
#     ('AVG', '369'),
#     ('MIN', '6.0'),
#     ('AVG', '137'),
#     ('FG', '3'),
#     ('FGA', '161'),
#     ('PCT', '2.6'),
#     ('FG', '150'),
#     ('FGA', '44'),
#     ('PCT', '56'),
#     ('FT', '455'),
#     ('FTA', '7.3')]}],
#  'sel': <Selector xpath=None data='<html id="ctl00_html" lang="en" class=" '>,
#  'stats_url': 'http://goheels.com/services/responsive-roster-bio.ashx?type=stats&rp_id=12642&path=wbball&year=2017&player_id=3674'}

# %%
#formats for json file
to_dump = [p.copy() for p in players]
for p in to_dump:
    p.pop('sel')
with open('scraped_players.json', 'w') as f:
    json.dump(to_dump, f)

# %%
cat scraped_players.json | cut -c 1-100
# Out:
# [{"No.": "1", "href": "/roster.aspx?rp_id=12642", "Name": "Taylor Koenen", "Pos.": "G", "Ht.": "6-2"

# %%
to_dump[0]
# Out:
# {'Hometown / High School': 'Savage, Minn. / Shakopee',
#  'Ht.': '6-2',
#  'Name': 'Taylor Koenen',
#  'No.': '1',
#  'Pos.': 'G',
#  'Yr.': 'So.',
#  'bio': "\r\n                        Biography\r\n                                                    \r\n                            FRESHMAN SEASON 2016-17\r\nAveraged 6.6 points and 5.1 rebounds in first season at North Carolina • Played in all 31 games and started 12 of the final 13 games of the season • Finished the year strong by averaging 10.0 points and a team-leading 7.4 rebounds in the last five games of the season • Registered first career double-double with 11 points and 11 rebounds in the win over Pitt in the first round of the ACC Tournament • Scored a season-high 17 points in the victory over Georgia Tech • Scored in double figures in six games overall, including four of the last six games of 2016-17.\xa0\r\n\r\nPREP/PERSONAL\r\nFive-star rated by ESPN • Ranked 11th best guard and 43rd overall in 2016 class by ESPN • Top-ranked player in the state of Minnesota by Breakdown Sports USA • 2016 Gatorade Minnesota Player of the Year • Earned 15 varsity letters (six in tennis, five in basketball and four in softball) • First Shakopee girl or boy basketball player to score 2,000 career points • Holds eight school records including points, three-pointers, rebounds, assists and steals • Academic all-state team member, ranking in the top 10 percent of her class of nearly 500 students • Favorite high school memory was a three-quarter court shot as a sophomore that ended up on ESPN's Top10 Plays • Named all-conference five times in basketball and tennis and twice in softball • Averaged 21.1 points, 8.1 rebounds, 3.3 assets and 3.2 steals per game as a senior • First team Associated Press All-State as a junior in 2015 • Averaged 21 points, eight rebounds, four assists, three steals and two blocks per game in junior season • Four-time all-academic selection • Competed for Minnesota Stars for two years and Minnesota Fury for six years • Daughter of Doug and Kelli Koenen, and has a younger brother Tanner.\r\n                        \r\n                    ",
#  'href': '/roster.aspx?rp_id=12642',
#  'img': '/images/2017/10/2/Koenen_Taylor_2017_84.jpg?width=300',
#  'raw_stats': [{'Total Career Statistics': [('GP', '62'),
#     ('GS', '43'),
#     ('Minutes', '1916'),
#     ('Totals', '30.9'),
#     ('3-Point', '178'),
#     ('Free-Throws', '523'),
#     ('Rebounds', '.340'),
#     ('PF', '32'),
#     ('FO', '181'),
#     ('AST', '.177'),
#     ('AST/G', '67'),
#     ('T/O', '111'),
#     ('BLK', '.604'),
#     ('STL', '114'),
#     ('PTS', '255'),
#     ('AVG', '369'),
#     ('MIN', '6.0'),
#     ('AVG', '137'),
#     ('FG', '3'),
#     ('FGA', '161'),
#     ('PCT', '2.6'),
#     ('FG', '150'),
#     ('FGA', '44'),
#     ('PCT', '56'),
#     ('FT', '455'),
#     ('FTA', '7.3')]},
#   {"['2016-17']": [('GP', '62'),
#     ('GS', '43'),
#     ('Minutes', '1916'),
#     ('Totals', '30.9'),
#     ('3-Point', '178'),
#     ('Free-Throws', '523'),
#     ('Rebounds', '.340'),
#     ('PF', '32'),
#     ('FO', '181'),
#     ('AST', '.177'),
#     ('AST/G', '67'),
#     ('T/O', '111'),
#     ('BLK', '.604'),
#     ('STL', '114'),
#     ('PTS', '255'),
#     ('AVG', '369'),
#     ('MIN', '6.0'),
#     ('AVG', '137'),
#     ('FG', '3'),
#     ('FGA', '161'),
#     ('PCT', '2.6'),
#     ('FG', '150'),
#     ('FGA', '44'),
#     ('PCT', '56'),
#     ('FT', '455'),
#     ('FTA', '7.3')]},
#   {"['2017-18']": [('GP', '62'),
#     ('GS', '43'),
#     ('Minutes', '1916'),
#     ('Totals', '30.9'),
#     ('3-Point', '178'),
#     ('Free-Throws', '523'),
#     ('Rebounds', '.340'),
#     ('PF', '32'),
#     ('FO', '181'),
#     ('AST', '.177'),
#     ('AST/G', '67'),
#     ('T/O', '111'),
#     ('BLK', '.604'),
#     ('STL', '114'),
#     ('PTS', '255'),
#     ('AVG', '369'),
#     ('MIN', '6.0'),
#     ('AVG', '137'),
#     ('FG', '3'),
#     ('FGA', '161'),
#     ('PCT', '2.6'),
#     ('FG', '150'),
#     ('FGA', '44'),
#     ('PCT', '56'),
#     ('FT', '455'),
#     ('FTA', '7.3')]}],
#  'stats_url': 'http://goheels.com/services/responsive-roster-bio.ashx?type=stats&rp_id=12642&path=wbball&year=2017&player_id=3674'}

# %%
df = pd.read_json("scraped_players.json")

# %%
#displays chart from json file
df
# Out:
#                       Hometown / High School   Ht.             Name  No. Pos.  \
# 0                   Savage, Minn. / Shakopee   6-2    Taylor Koenen    1    G
# 1                      Richmond, Va. / Cosby   6-0    Jocelyn Jones    4    G
# 2           Wesley Chapel, N.C. / Weddington  5-11  Stephanie Watts    5    G
# 3              Cove City, N.C. / West Craven   5-8     Jamie Cherry   10    G
# 4            Newburgh, Ind. / Reitz Memorial   6-4   Emily Sullivan   11    F
# 5                  Raleigh, N.C. / Millbrook  5-10     Dazia Powell   13    G
# 6         Chapel Hill, N.C. / Durham Academy   5-8      Liz Roberts   14    G
# 7           Raleigh, N.C. / Cardinal Gibbons   6-0     Olivia Smith   15    G
# 8       Purlear, N.C. / Forest Trail Academy   5-8      Leah Church   20    G
# 9            Tarboro, N.C. / Page/Vanderbilt   5-9        Paris Kea   22    G
# 10        Orlando, Fla. / Lake Highland Prep  5-10  Destinee Walker   24    G
# 11                   Columbia, S.C. / Dreher   6-2   Jaelynn Murray   30    F
# 12  Dorchester, England / Hamden Country Day   6-6    Naomi Van Nes   34    C
# 13    Matthews, N.C. / Providence Day School   6-4   Janelle Bailey   44    C
#
#       Yr.                                                bio  \
# 0     So.  \r\n                        Biography\r\n     ...
# 1   R-Fr.  \r\n                        Biography\r\n     ...
# 2     Jr.  \r\n                        Biography\r\n     ...
# 3     Sr.  \r\n                        Biography\r\n     ...
# 4     So.  \r\n                        Biography\r\n     ...
# 5     Fr.  \r\n                        Biography\r\n     ...
# 6     So.  \r\n                        Biography\r\n     ...
# 7     So.  \r\n                        Biography\r\n     ...
# 8     Fr.  \r\n                        Biography\r\n     ...
# 9   R-Jr.  \r\n                        Biography\r\n     ...
# 10    Jr.  \r\n                        Biography\r\n     ...
# 11    Fr.  \r\n                        Biography\r\n     ...
# 12    So.  \r\n                        Biography\r\n     ...
# 13    Fr.  \r\n                        Biography\r\n     ...
#
#                         href  \
# 0   /roster.aspx?rp_id=12642
# 1   /roster.aspx?rp_id=12643
# 2   /roster.aspx?rp_id=12644
# 3   /roster.aspx?rp_id=12645
# 4   /roster.aspx?rp_id=12646
# 5   /roster.aspx?rp_id=12647
# 6   /roster.aspx?rp_id=12648
# 7   /roster.aspx?rp_id=12649
# 8   /roster.aspx?rp_id=12650
# 9   /roster.aspx?rp_id=12651
# 10  /roster.aspx?rp_id=12652
# 11  /roster.aspx?rp_id=12653
# 12  /roster.aspx?rp_id=12654
# 13  /roster.aspx?rp_id=12655
#
#                                                   img  \
# 0   /images/2017/10/2/Koenen_Taylor_2017_84.jpg?wi...
# 1   /images/2017/10/2/Jones_Jocelyn_2017_124.jpg?w...
# 2   /images/2017/10/2/Watts_Stephanie_2017_79.jpg?...
# 3   /images/2017/10/2/Cherry_Jamie_2017_76.jpg?wid...
# 4   /images/2017/10/2/Sullivan_Emily_2017_143.jpg?...
# 5   /images/2017/10/2/Powell_Dazia_2017_94.jpg?wid...
# 6   /images/2017/10/3/Roberts_Liz_2017_66.jpg?widt...
# 7   /images/2017/10/2/Smith_Olivia_2017_61.jpg?wid...
# 8   /images/2017/10/2/Church_Leah_2017_105.jpg?wid...
# 9   /images/2017/10/2/Kea_Paris_2017_14.jpg?width=300
# 10  /images/2017/10/2/Walker_Destinee_2017_113.jpg...
# 11  /images/2017/10/2/Murray_Jaelynn_2017_50.jpg?w...
# 12  /images/2017/10/2/Van_Nes_Naomi_2017_129.jpg?w...
# 13  /images/2017/10/2/Bailey_Janelle_2017_88.jpg?w...
#
#                                             raw_stats  \
# 0   [{'Total Career Statistics': [['GP', '62'], ['...
# 1   [{'Total Career Statistics': [['GP', '31'], ['...
# 2   [{'Total Career Statistics': [['GP', '58'], ['...
# 3   [{'Total Career Statistics': [['GP', '129'], [...
# 4   [{'Total Career Statistics': [['GP', '43'], ['...
# 5                                                 NaN
# 6   [{'Total Career Statistics': [['GP', '14'], ['...
# 7   [{'Total Career Statistics': [['GP', '47'], ['...
# 8   [{'Total Career Statistics': [['GP', '28'], ['...
# 9   [{'Total Career Statistics': [['GP', '62'], ['...
# 10  [{'Total Career Statistics': [['GP', '53'], ['...
# 11  [{'Total Career Statistics': [['GP', '31'], ['...
# 12  [{'Total Career Statistics': [['GP', '39'], ['...
# 13  [{'Total Career Statistics': [['GP', '31'], ['...
#
#                                             stats_url
# 0   http://goheels.com/services/responsive-roster-...
# 1   http://goheels.com/services/responsive-roster-...
# 2   http://goheels.com/services/responsive-roster-...
# 3   http://goheels.com/services/responsive-roster-...
# 4   http://goheels.com/services/responsive-roster-...
# 5   http://goheels.com/services/responsive-roster-...
# 6   http://goheels.com/services/responsive-roster-...
# 7   http://goheels.com/services/responsive-roster-...
# 8   http://goheels.com/services/responsive-roster-...
# 9   http://goheels.com/services/responsive-roster-...
# 10  http://goheels.com/services/responsive-roster-...
# 11  http://goheels.com/services/responsive-roster-...
# 12  http://goheels.com/services/responsive-roster-...
# 13  http://goheels.com/services/responsive-roster-...

# %%
df.columns
# Out:
# Index(['Hometown / High School', 'Ht.', 'Name', 'No.', 'Pos.', 'Yr.', 'bio',
#        'href', 'img', 'raw_stats', 'stats_url'],
#       dtype='object')

# %%
df = df.set_index("Name")

# %%
df.loc["Paris Kea"]
# Out:
# Hometown / High School                      Tarboro, N.C. / Page/Vanderbilt
# Ht.                                                                     5-9
# No.                                                                      22
# Pos.                                                                      G
# Yr.                                                                   R-Jr.
# bio                       \r\n                        Biography\r\n     ...
# href                                               /roster.aspx?rp_id=12651
# img                       /images/2017/10/2/Kea_Paris_2017_14.jpg?width=300
# raw_stats                 [{'Total Career Statistics': [['GP', '62'], ['...
# stats_url                 http://goheels.com/services/responsive-roster-...
# Name: Paris Kea, dtype: object

# %%
#womxn's basketball team members grouped by year
grouped = df.groupby("Yr.")
type(grouped)
grouped.groups
# Out:
# {'Fr.': Index(['Dazia Powell', 'Leah Church', 'Jaelynn Murray', 'Janelle Bailey'], dtype='object', name='Name'),
#  'Jr.': Index(['Stephanie Watts', 'Destinee Walker'], dtype='object', name='Name'),
#  'R-Fr.': Index(['Jocelyn Jones'], dtype='object', name='Name'),
#  'R-Jr.': Index(['Paris Kea'], dtype='object', name='Name'),
#  'So.': Index(['Taylor Koenen', 'Emily Sullivan', 'Liz Roberts', 'Olivia Smith',
#         'Naomi Van Nes'],
#        dtype='object', name='Name'),
#  'Sr.': Index(['Jamie Cherry'], dtype='object', name='Name')}

# %%
players[0]['raw_stats'][1]
# Out:
# {"['2016-17']": [('GP', '62'),
#   ('GS', '43'),
#   ('Minutes', '1916'),
#   ('Totals', '30.9'),
#   ('3-Point', '178'),
#   ('Free-Throws', '523'),
#   ('Rebounds', '.340'),
#   ('PF', '32'),
#   ('FO', '181'),
#   ('AST', '.177'),
#   ('AST/G', '67'),
#   ('T/O', '111'),
#   ('BLK', '.604'),
#   ('STL', '114'),
#   ('PTS', '255'),
#   ('AVG', '369'),
#   ('MIN', '6.0'),
#   ('AVG', '137'),
#   ('FG', '3'),
#   ('FGA', '161'),
#   ('PCT', '2.6'),
#   ('FG', '150'),
#   ('FGA', '44'),
#   ('PCT', '56'),
#   ('FT', '455'),
#   ('FTA', '7.3')]}

# %%
#womxn's basketball team members grouped by position
grouped = df.groupby("Pos.")
type(grouped)
grouped.groups
# Out:
# {'C': Index(['Naomi Van Nes', 'Janelle Bailey'], dtype='object', name='Name'),
#  'F': Index(['Emily Sullivan', 'Jaelynn Murray'], dtype='object', name='Name'),
#  'G': Index(['Taylor Koenen', 'Jocelyn Jones', 'Stephanie Watts', 'Jamie Cherry',
#         'Dazia Powell', 'Liz Roberts', 'Olivia Smith', 'Leah Church',
#         'Paris Kea', 'Destinee Walker'],
#        dtype='object', name='Name')}
